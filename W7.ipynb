# %% [markdown]
# ### 1.Import neccessary Libraries

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report, accuracy_score

# %% [markdown]
# ### 2.Import Train Data

# %%
df=pd.read_csv("train.csv")

# %% [markdown]
# ### 3.Check Shape of Data

# %%
print("Shape of data is :",df.shape)
# Out:
# Shape of data is : (42000, 785)

# %% [markdown]
# ### 4.Select 10% of data from expt.

# %%
df1=df.sample(frac=0.1)

# %%
print(df1.isnull().sum())
# Out:
# label       0
# pixel0      0
# pixel1      0
# pixel2      0
# pixel3      0
#            ..
# pixel779    0
# pixel780    0
# pixel781    0
# pixel782    0
# pixel783    0
# Length: 785, dtype: int64

# %% [markdown]
# ### 5.Print shape of Selected dataset

# %%
print(df1.shape)
# Out:
# (4200, 785)

# %% [markdown]
# ### 6.Look at the top 5 rows

# %%
print(df1.head())
# Out:
#        label  pixel0  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  \
# 40999      6       0       0       0       0       0       0       0       0
# 9725       7       0       0       0       0       0       0       0       0
# 13057      4       0       0       0       0       0       0       0       0
# 5710       5       0       0       0       0       0       0       0       0
# 7670       8       0       0       0       0       0       0       0       0
#
#        pixel8  ...  pixel774  pixel775  pixel776  pixel777  pixel778  \
# 40999       0  ...         0         0         0         0         0
# 9725        0  ...         0         0         0         0         0
# 13057       0  ...         0         0         0         0         0
# 5710        0  ...         0         0         0         0         0
# 7670        0  ...         0         0         0         0         0
#
#        pixel779  pixel780  pixel781  pixel782  pixel783
# 40999         0         0         0         0         0
# 9725          0         0         0         0         0
# 13057         0         0         0         0         0
# 5710          0         0         0         0         0
# 7670          0         0         0         0         0
#
# [5 rows x 785 columns]

# %% [markdown]
# ### 7.Find no.of unique class labels

# %%
df1['label'].nunique()
# Out:
# 10

# %% [markdown]
# ### 8.Print the no of examples for each class label

# %%
df1['label'].value_counts()
# Out:
# label
# 1    485
# 0    425
# 3    423
# 6    419
# 8    419
# 7    413
# 4    410
# 5    403
# 9    403
# 2    400
# Name: count, dtype: int64

# %% [markdown]
# ### 9.Prepare X and Y

# %%
X = df1.drop(columns=['label']) 
Y = df1['label']

# %% [markdown]
# ### 10.Visualization the image of first 5 digital in X-also print the class label in

# %%
# Assuming dataset contains image data in pixel values
for i in range(5):
    plt.imshow(X.iloc[i].values.reshape(28, 28), cmap='gray')  # Change shape accordingly
    plt.title(f"Class: {Y.iloc[i]}")
    plt.show()

# %% [markdown]
# ### 11.split train dataset into training(75%) & validation set(25%)

# %%
X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y, test_size=0.75, random_state=42)

# %% [markdown]
# ### 12.Fit KNN Classifies to training data
# ### 13.Default parameters n-neighbors-5,metric='minkowski' p=2

# %%
knn = KNeighborsClassifier(n_neighbors=5, metric='minkowski', p=2)  # Default parameters
knn.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ### 14.predict the validation set results

# %%
Y_pred = knn.predict(X_validation)
print(Y_pred)
# Out:
# [4 9 3 ... 2 8 5]

# %% [markdown]
# ### 15.print confusion matrix

# %%
conf_matrix = confusion_matrix(Y_validation, Y_pred)
print(conf_matrix)
# Out:
# [[287   1   0   0   0   2   3   0   0   0]
#  [  0 355   1   2   0   0   0   0   0   0]
#  [  8  35 247  11   3   0   3  15   6   2]
#  [  1  12   3 306   0   5   1   5   5   3]
#  [  0  11   0   0 244   0   3   2   0  30]
#  [  1   8   0  12   2 228   6   1   4   8]
#  [  6   5   1   0   0   2 283   0   2   0]
#  [  0  14   0   0   3   1   0 306   0  14]
#  [  0  17   0  13   4   7   3   1 253   9]
#  [  2   4   0   2  21   1   0  24   0 270]]

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# %%
ConfusionMatrixDisplay.from_predictions(Y_validation, Y_pred, cmap='viridis')

# %% [markdown]
# ### 16.printing classification report and accuracy

# %%
print(classification_report(Y_validation, Y_pred))
print(f"Accuracy: {accuracy_score(Y_validation, Y_pred) * 100:.2f}%")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       293
#            1       0.77      0.99      0.87       358
#            2       0.98      0.75      0.85       330
#            3       0.88      0.90      0.89       341
#            4       0.88      0.84      0.86       290
#            5       0.93      0.84      0.88       270
#            6       0.94      0.95      0.94       299
#            7       0.86      0.91      0.88       338
#            8       0.94      0.82      0.88       307
#            9       0.80      0.83      0.82       324
#
#     accuracy                           0.88      3150
#    macro avg       0.89      0.88      0.88      3150
# weighted avg       0.89      0.88      0.88      3150
#
# Accuracy: 88.22%

# %% [markdown]
# ### 17.Visualize the image of first 5 digits in X-test also print the predicted

# %%
for i in range(5):
    plt.imshow(X_validation.iloc[i].values.reshape(28, 28), cmap='gray')  # Change shape if needed
    plt.title(f"Predicted Label: {Y_pred[i]}")
    plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df.head()
df.shape
df.info
df.head(1)
#to convert into image
plt.imshow(df.iloc[3, 1:].values.reshape(28, 28), cmap='grey')
print(df.iloc[3, 0])
#take only 10% of total data since applying knn
mf = df.sample(frac=0.10)
y = mf.iloc[:, 0]
X = mf.iloc[:, 1:]
# Out:
# 4

# %%
print(df1.isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(df1.isnull().sum())
#
# NameError: name 'df1' is not defined
